# %%
import robosuite as suite
import numpy as np
import imageio
# Out:
# [robosuite WARNING] No private macro file found! (macros.py:53)
# [robosuite WARNING] It is recommended to use a private macro file (macros.py:54)
# [robosuite WARNING] To setup, run: python /mnt/efs/rohingarg/cri/robotics-rl/.venv/lib/python3.10/site-packages/robosuite/scripts/setup_macros.py (macros.py:55)
# [robosuite WARNING] Could not import robosuite_models. Some robots may not be available. If you want to use these robots, please install robosuite_models from source (https://github.com/ARISE-Initiative/robosuite_models) or through pip install. (__init__.py:30)
# [robosuite WARNING] Could not load the mink-based whole-body IK. Make sure you install related import properly, otherwise you will not be able to use the default IK controller setting for GR1 robot. (__init__.py:40)

# %%
# create environment instance
env = suite.make(
    env_name="Lift", # try with other tasks like "Stack" and "Door"
    robots="Panda",  # try with other robots like "Sawyer" and "Jaco"
    has_renderer=False,
    has_offscreen_renderer=True,
    use_camera_obs=True,
    camera_names="agentview",
    camera_heights=256,
    camera_widths=256,
)
frames = []

# reset the environment
env.reset()

for i in range(1000):
    action = np.random.randn(*env.action_spec[0].shape) * 0.1
    obs, reward, done, info = env.step(action)  # take action in the environment
    frames.append(obs["agentview_image"])

imageio.mimsave("rollout.mp4", frames, fps=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # create environment instance
# ----> 2 env = suite.make(
#       3     env_name="Lift", # try with other tasks like "Stack" and "Door"
#       4     robots="Panda",  # try with other robots like "Sawyer" and "Jaco"
#       5     has_renderer=False,
#       6     has_offscreen_renderer=True,
#       7     use_camera_obs=True,
#       8     camera_names="agentview",
#       9     camera_heights=256,
#      10     camera_widths=256,
#      11 )
#      12 frames = []
#      14 # reset the environment
#
# NameError: name 'suite' is not defined

# %%
env._check_success()
# Out:
# np.False_

# %%
for key, val in obs.items():
    print(f"{key}: {val.shape}")

# print(env.robots[0].controller)
print(obs["object-state"])
# Out:
# robot0_joint_pos: (7,)
# robot0_joint_pos_cos: (7,)
# robot0_joint_pos_sin: (7,)
# robot0_joint_vel: (7,)
# robot0_eef_pos: (3,)
# robot0_eef_quat: (4,)
# robot0_eef_quat_site: (4,)
# robot0_gripper_qpos: (2,)
# robot0_gripper_qvel: (2,)
# agentview_image: (256, 256, 3)
# cube_pos: (3,)
# cube_quat: (4,)
# gripper_to_cube_pos: (3,)
# robot0_proprio-state: (43,)
# object-state: (10,)
# [-2.66589102e-02 -2.53768999e-02  8.21234649e-01  6.37266721e-18
#   7.80417513e-18  7.61070587e-01  6.48669070e-01  1.04068728e-01
#  -1.70094421e-01 -2.61944217e-01]

# %%
# %load_ext autoreload
# %autoreload 2

from envs import RobosuiteGymWrapper

env = RobosuiteGymWrapper()
obs, info = env.reset()

print(f"obs: {obs.shape}")
print(f"info: {info}")

for i in range(20):
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    print(f"Reward: {reward:.4f}, Terminated: {terminated}, Truncated: {truncated}")
# Out:
# [robosuite INFO] Loading controller configuration from: /mnt/efs/rohingarg/cri/robotics-rl/.venv/lib/python3.10/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# [robosuite INFO] Loading controller configuration from: /mnt/efs/rohingarg/cri/robotics-rl/.venv/lib/python3.10/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# [robosuite INFO] Loading controller configuration from: /mnt/efs/rohingarg/cri/robotics-rl/.venv/lib/python3.10/site-packages/robosuite/controllers/config/robots/default_panda.json (composite_controller_factory.py:121)
# obs: (11,)
# info: {}
# Reward: 0.0089, Terminated: False, Truncated: False
# Reward: 0.0081, Terminated: False, Truncated: False
# Reward: 0.0080, Terminated: False, Truncated: False
# Reward: 0.0094, Terminated: False, Truncated: False
# Reward: 0.0097, Terminated: False, Truncated: False
# Reward: 0.0097, Terminated: False, Truncated: False
# Reward: 0.0088, Terminated: False, Truncated: False
# Reward: 0.0071, Terminated: False, Truncated: False
# Reward: 0.0050, Terminated: False, Truncated: False
# Reward: 0.0043, Terminated: False, Truncated: False
# Reward: 0.0044, Terminated: False, Truncated: False
# Reward: 0.0055, Terminated: False, Truncated: False
# Reward: 0.0066, Terminated: False, Truncated: False
# Reward: 0.0071, Terminated: False, Truncated: False
# Reward: 0.0087, Terminated: False, Truncated: False
# Reward: 0.0094, Terminated: False, Truncated: False
# Reward: 0.0080, Terminated: False, Truncated: False
# Reward: 0.0078, Terminated: False, Truncated: False
# Reward: 0.0087, Terminated: False, Truncated: False
# Reward: 0.0079, Terminated: False, Truncated: False
